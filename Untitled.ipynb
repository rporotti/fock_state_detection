# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from codes.common.parser import parser
from codes.environment.multichannel import SimpleCavityEnv
import numpy as np

args = vars(parser.parse_args(args=[]))


# args["N_states"]=15
# args["substeps"]=1
# args["fixed_seed"]=True
# args["timesteps"]=100
# args["T_max"]=Tmax
# args["meas_rate"]=2
# args["multiplier"]=limit
args["init_state"]="0+2"
args["target_state"]="0+2"
args["meas_rate"]=1
args["decay"]=0
args["dephasing"]=10

args["fixed_seed"]=True

env=SimpleCavityEnv(args,testing=True, viewer=True)     

obs=env.reset()
print(env.Rho[0,2])
for i in range(env.T):
    action=[0,0]
    obs, r, done, _ = env.step(action)
    #print(np.diag(env.Rho))
    #print(r)
env.render()
print(env.Rho[0,2])
#print(env.probs_final)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# (0.4999999999999999+0j)
# /Users/rporott/Desktop/git/fock_state_detection/codes/environment/multichannel.py:736: UserWarning: Attempting to set identical bottom == top == -0.0 results in singular transformations; automatically expanding.
# (4.197302286348803e-14+0j)
