# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from codes.common.parser import parser
from codes.environment.multichannel import SimpleCavityEnv


args = vars(parser.parse_args(args=[]))


# args["N_states"]=15
# args["substeps"]=1
# args["fixed_seed"]=True
# args["timesteps"]=100
# args["T_max"]=Tmax
# args["meas_rate"]=2
# args["multiplier"]=limit
args["init_state"]="0+2"
args["target_state"]="0+2"
args["meas_rate"]=10
args["decay"]=1
args["dephasing"]=10

args["fixed_seed"]=True

env=SimpleCavityEnv(args,testing=True, viewer=True)     

obs=env.reset()
print(env.Rho[0,2])
for i in range(env.T):
    action=[0,0]
    obs, r, done, _ = env.step(action)
    print(r)
env.render()
print(env.Rho[0,2])
#print(env.probs_final)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# (0.4999999999999999+0j)
# 0.8517997380367411
# 0.7637435187523812
# 0.7555200883651859
# 0.6864369053491449
# 0.6642097110559548
# 0.6485849781487921
# 0.5963280068755958
# 0.5805827057884363
# 0.5706387742615542
# 0.5384245393638327
# 0.5082261658808125
# 0.5141991770661947
# 0.5027707338762244
# 0.52257304308234
# 0.5153935908450621
# 0.5083838767201522
# 0.49464085441352473
# 0.457889475277891
# 0.48905544914108107
# 0.4829891153988539
# 0.47933717716977414
# 0.492581078242269
# 0.49294545048419547
# 0.4975715341553578
# 0.4991569498077057
# 0.49722287561477635
# 0.49879984511487363
# 0.49850643695758284
# 0.4975582977679791
# 0.4980893213756482
# 0.4993901972069172
# 0.4993256588369691
# 0.4995762921782947
# 0.49946670648171526
# 0.4989566304291766
# 0.49921071635960124
# 0.4997653768901495
# 0.499770593347468
# 0.49948604626703047
# 0.4996371619802705
# 0.49971216052381384
# 0.49957474091830056
# 0.49909296837176387
# 0.49781058958411933
# 0.49792987197458677
# 0.4986624884658081
# 0.4974978145411001
# 0.49806836428227325
# 0.49727016001528723
# 0.49765238975232357
# 0.49837815532143853
# 0.4983324199337177
# 0.49813519594769057
# 0.4983545905903628
# 0.4993467368343624
# 0.4994162970693967
# 0.49948872895355556
# 0.4997429816493523
# 0.4999114038983199
# 0.49990931259900506
# 0.4999721416847221
# 0.499923829486781
# 0.4999751253885535
# 0.49995088040308067
# 0.49991371576009036
# 0.4999037834685311
# 0.499845194855952
# 0.49996991226327403
# 0.4999927716263309
# 0.4999972470008376
# 0.49999880179025735
# 0.4999967630740261
# 0.49999569229317503
# 0.4999969676604389
# 0.49999916013630985
# 0.4999997003972381
# 0.49999998803613976
# 0.5000000072551666
# 0.4999999925458497
# 0.499999985428325
# 0.49999997213551683
# 0.49999999936960826
# 0.5000000050963207
# 0.4999999836163264
# 0.4999999313009663
# 0.4999999151869227
# 0.4999998549476498
# 0.4999998992429096
# 0.4999999774682431
# 0.49999996441306205
# 0.49999996361821847
# 0.49999996984020206
# 0.4999999802378943
# 0.4999999857481822
# 0.49999999940329587
# 0.49999999892795366
# 0.49999999912103044
# 0.49999999854138466
# 0.5000000045523164
# 0.4999999996733871
# /Users/rporott/Desktop/git/fock_state_detection/codes/environment/multichannel.py:726: UserWarning: Attempting to set identical bottom == top == -0.0 results in singular transformations; automatically expanding.
#   x=np.linspace(1,self.ep*self.ntraj,len(self.total_rewards))
# (2.1747661573959443e-18+0j)
